# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
b = pd.read_csv("yelp_boston.csv")
g = pd.read_json("MassTowns.geojson")
b.categories = b.categories.apply(lambda x: x.replace("[", "").replace("]", "").replace(",","").lower()[1:-1].split('"'))
b.categories = b.categories.apply(lambda x: [i for i in x if i!= " "])
b=b.rename(columns={"search category": "search_cat"})

# %%
b.head()
# Out:
#              name                                            url  \
# 0      Wheelhouse    http://www.yelp.com/biz/wheelhouse-boston-3
# 1  Tenoch Mexican  http://www.yelp.com/biz/tenoch-mexican-boston
# 2            O Ya            http://www.yelp.com/biz/o-ya-boston
# 3          Locale          http://www.yelp.com/biz/locale-boston
# 4  Neptune Oyster  http://www.yelp.com/biz/neptune-oyster-boston
#
#    review_count                                         categories  rating  \
# 0           101  [breakfast & brunch, breakfast_brunch, burgers...     4.5
# 1           121                                 [mexican, mexican]     4.5
# 2           450                               [japanese, japanese]     4.5
# 3           121                   [italian, italian, pizza, pizza]     4.5
# 4          2487        [seafood, seafood, live/raw food, raw_food]     4.5
#
#                                         snippet_text  \
# 0  After going to Wheelhouse, you'll never order ...
# 1  So it's official, folks. We've finished our sa...
# 2  My husband and I came here to celebrate our 20...
# 3  Truly thankful that we stumbled on Locale whil...
# 4  Best lobster roll on the whole trip..... and I...
#
#                                             location        neighborhood  \
# 0  {"cross_streets": "Milk St & Batterymarch Arm"...  Financial District
# 1  {"city": "Boston", "display_address": ["3 Lewi...           North End
# 2  {"city": "Boston", "display_address": ["9 E St...          Waterfront
# 3  {"cross_streets": "Fleet St & Tileston St", "c...           North End
# 4  {"cross_streets": "Hull St & Stillman St", "ci...           North End
#
#     latitude  longitude   search_cat
# 0  42.357926 -71.053962  restaurants
# 1  42.363309 -71.051800  restaurants
# 2  42.351408 -71.056867  restaurants
# 3  42.365085 -71.053187  restaurants
# 4  42.363618 -71.056012  restaurants

# %%
all_cats = []
for c in b.categories:
    for i in range(len(c)):
        if c[i] not in all_cats:
            all_cats.append(c[i])

# %%
all_cats
# Out:
# ['breakfast & brunch',
#  'breakfast_brunch',
#  'burgers',
#  'sandwiches',
#  'mexican',
#  'japanese',
#  'italian',
#  'pizza',
#  'seafood',
#  'live/raw food',
#  'raw_food',
#  'american (new)',
#  'newamerican',
#  'mediterranean',
#  'vegan',
#  'gluten-free',
#  'gluten_free',
#  'spanish',
#  'wine bars',
#  'wine_bars',
#  'tapas/small plates',
#  'tapasmallplates',
#  'salad',
#  'juice bars & smoothies',
#  'juicebars',
#  'vegetarian',
#  'indian',
#  'indpak',
#  'belgian',
#  'american (traditional)',
#  'tradamerican',
#  'pubs',
#  'korean',
#  'asian fusion',
#  'asianfusion',
#  'lounges',
#  'coffee & tea',
#  'coffee',
#  'cafes',
#  'delis',
#  'grocery',
#  'bakeries',
#  'gastropubs',
#  'bars',
#  'cocktail bars',
#  'cocktailbars',
#  'desserts',
#  'french',
#  'steakhouses',
#  'steak',
#  'cheese shops',
#  'cheese',
#  'sushi bars',
#  'sushi',
#  'bubble tea',
#  'bubbletea',
#  'vietnamese',
#  'caterers',
#  'catering',
#  'cheesesteaks',
#  'diners',
#  'turkish',
#  'falafel',
#  'pakistani',
#  'bangladeshi',
#  'himalayan/nepalese',
#  'himalayan',
#  'halal',
#  'fast food',
#  'hotdogs',
#  'hot pot',
#  'hotpot',
#  'chinese',
#  'ramen',
#  'mongolian',
#  'dim sum',
#  'dimsum',
#  'cantonese',
#  'latin american',
#  'latin',
#  'food trucks',
#  'foodtrucks',
#  'thai',
#  'ice cream & frozen yogurt',
#  'icecream',
#  'donuts',
#  'food stands',
#  'foodstands',
#  'cupcakes',
#  'greek',
#  'ethnic food',
#  'ethnicmarkets',
#  'armenian',
#  'middle eastern',
#  'mideastern',
#  'polish',
#  'ukrainian',
#  'shopping']

# %%
# cuisines
cus_map = {'american':['burgers', 'american (new)',
 'newamerican',  'american (traditional)',
 'tradamerican', 'steakhouses',
 'steak', 'cheesesteaks', 'fast food',
 'hotdogs'],
'breakfast':['breakfast & brunch',
 'breakfast_brunch', 'diners'],
'mexican':['mexican'],
'japanese':['japanese', 'sushi bars',
 'sushi', 'ramen'],
'vietnamese':['vietnamese'],
'italian':['italian',
 'pizza'],
'seafood':['seafood',
 'live/raw food',
 'raw_food'],
'mediterranean':['mediterranean', 'greek'],
'sandwich':['sandwiches', 'deli'],
'healthy':['salad',
 'juice bars & smoothies',
 'juicebars'],
'spanish':['spanish', 'tapas/small plates',
 'tapasmallplates'],
'asian_fusion':['asian fusion',
 'asianfusion'],
'indian_pakistani':['indian',
 'indpak', 'bangladeshi', 'pakistani'],
'french':['french'],
'chinese':['hot pot',
 'hotpot',
 'chinese', 'dim sum',
 'dimsum',
 'cantonese'],
'latin':['latin american',
 'latin'],
'thai':['thai'],
'middle_east':['armenian',
 'middle eastern',
 'mideastern'],
'polish_ukr':['polish',
 'ukrainian']}

# establishments
estab_dict = {'bars' : ['wine bars',
 'wine_bars', 'bars',
 'cocktail bars',
 'cocktailbars', 'pubs', 'gastropubs'],
'bakery/dessert':['ice cream & frozen yogurt',
 'icecream',
 'donuts', 'bakeries', 'desserts', 'cupcakes'],
'coffee/cafe':['coffee & tea',
 'coffee',
 'cafes']}

# %%
cus_map.keys()
# Out:
# dict_keys(['american', 'breakfast', 'mexican', 'japanese', 'vietnamese', 'italian', 'seafood', 'mediterranean', 'sandwich', 'healthy', 'spanish', 'asian_fusion', 'indian_pakistani', 'french', 'chinese', 'latin', 'thai', 'middle_east', 'polish_ukr'])

# %%
estab_dict.keys()
# Out:
# dict_keys(['bars', 'bakery/dessert', 'coffee/cafe'])

# %%
b['cuisine']=np.empty((len(b), 0)).tolist()
b['estab']=''

# %%
b.search_cat.unique()
# Out:
# array(['restaurants', 'coffee', 'newamerican', 'french', 'sandwiches',
#        'cafes', 'indpak', 'sushi', 'japanese', 'chinese', 'mexican',
#        'thai', 'pizza', 'donuts', 'bakeries', 'italian', 'vietnamese',
#        'ethnicmarkets'], dtype=object)

# %%
estab_map={"restaurants": "restaurant", "cafes": "coffee/cafe", "coffee": "coffee/cafe",
          "bakeries": "bakery/dessert", "donuts": "bakery/dessert"}

# %%
b.estab=b.search_cat.map(estab_map, 'ignore')
b.estab=b.estab.fillna("restaurant")

# %%
for key in cus_map.keys():
    for i,c in enumerate(b.categories):
        for x in c:
            if x in cus_map[key] and key not in b.loc[i,'cuisine']:
                b.loc[i, 'cuisine'].append(key)

for key in estab_dict.keys():
    for i,c in enumerate(b.categories):
        for x in c:
            if x in estab_dict[key]:
                b.loc[i, 'estab']=key
b
# Out:
#                              name  \
# 0                      Wheelhouse
# 1                  Tenoch Mexican
# 2                            O Ya
# 3                          Locale
# 4                  Neptune Oyster
# ..                            ...
# 338                     El Madina
# 339           The Shops at Porter
# 340  Bazaar International Gourmet
# 341          G Mart 2 Supermarket
# 342    Bonne Chance Cafe & Bakery
#
#                                                    url  review_count  \
# 0          http://www.yelp.com/biz/wheelhouse-boston-3           101
# 1        http://www.yelp.com/biz/tenoch-mexican-boston           121
# 2                  http://www.yelp.com/biz/o-ya-boston           450
# 3                http://www.yelp.com/biz/locale-boston           121
# 4        http://www.yelp.com/biz/neptune-oyster-boston          2487
# ..                                                 ...           ...
# 338           http://www.yelp.com/biz/el-madina-revere             8
# 339  http://www.yelp.com/biz/the-shops-at-porter-ca...            79
# 340  http://www.yelp.com/biz/bazaar-international-g...            52
# 341  http://www.yelp.com/biz/g-mart-2-supermarket-b...            48
# 342  http://www.yelp.com/biz/bonne-chance-cafe-and-...            22
#
#                                             categories  rating  \
# 0    [breakfast & brunch, breakfast_brunch, burgers...     4.5
# 1                                   [mexican, mexican]     4.5
# 2                                 [japanese, japanese]     4.5
# 3                     [italian, italian, pizza, pizza]     4.5
# 4          [seafood, seafood, live/raw food, raw_food]     4.5
# ..                                                 ...     ...
# 338  [mediterranean, mediterranean, middle eastern,...     4.5
# 339  [japanese, japanese, ethnic food, ethnicmarket...     4.0
# 340     [ethnic food, ethnicmarkets, grocery, grocery]     4.0
# 341     [grocery, grocery, ethnic food, ethnicmarkets]     4.0
# 342  [bakeries, bakeries, coffee & tea, coffee, eth...     4.0
#
#                                           snippet_text  \
# 0    After going to Wheelhouse, you'll never order ...
# 1    So it's official, folks. We've finished our sa...
# 2    My husband and I came here to celebrate our 20...
# 3    Truly thankful that we stumbled on Locale whil...
# 4    Best lobster roll on the whole trip..... and I...
# ..                                                 ...
# 338  I went in around closing tonight because I was...
# 339  This is like a small (chibi) version of the Ja...
# 340  The Bazaar at 1432 Beacon Street, Brookline Ma...
# 341  Everything is inexpensive! I was so surprised ...
# 342  I have to say.... I've not had anything else o...
#
#                                               location        neighborhood  \
# 0    {"cross_streets": "Milk St & Batterymarch Arm"...  Financial District
# 1    {"city": "Boston", "display_address": ["3 Lewi...           North End
# 2    {"city": "Boston", "display_address": ["9 E St...          Waterfront
# 3    {"cross_streets": "Fleet St & Tileston St", "c...           North End
# 4    {"cross_streets": "Hull St & Stillman St", "ci...           North End
# ..                                                 ...                 ...
# 338  {"city": "Revere", "display_address": ["148 Sq...                 NaN
# 339  {"city": "Cambridge", "display_address": ["Uni...       Porter Square
# 340  {"city": "Brookline", "display_address": ["143...     Coolidge Corner
# 341  {"cross_streets": "Beach St & Tufts St", "city...          Waterfront
# 342  {"cross_streets": "Traverse St & Market St", "...                 NaN
#
#       latitude  longitude     search_cat                          cuisine  \
# 0    42.357926 -71.053962    restaurants  [american, breakfast, sandwich]
# 1    42.363309 -71.051800    restaurants                        [mexican]
# 2    42.351408 -71.056867    restaurants                       [japanese]
# 3    42.365085 -71.053187    restaurants                        [italian]
# 4    42.363618 -71.056012    restaurants                        [seafood]
# ..         ...        ...            ...                              ...
# 338  42.423248 -71.009514  ethnicmarkets     [mediterranean, middle_east]
# 339  42.387192 -71.118778  ethnicmarkets                       [japanese]
# 340  42.341065 -71.126470  ethnicmarkets                               []
# 341  42.351569 -71.058365  ethnicmarkets                               []
# 342  42.364044 -71.059463  ethnicmarkets                               []
#
#            estab
# 0     restaurant
# 1     restaurant
# 2     restaurant
# 3     restaurant
# 4     restaurant
# ..           ...
# 338   restaurant
# 339   restaurant
# 340   restaurant
# 341   restaurant
# 342  coffee/cafe
#
# [343 rows x 13 columns]

# %%
b.estab.value_counts()
# Out:
# restaurant        236
# coffee/cafe        52
# bakery/dessert     36
# bars               19
# Name: estab, dtype: int64

# %%
b.neighborhood.unique()
# Out:
# array(['Financial District', 'North End', 'Waterfront', 'East Boston',
#        'Downtown', 'South End', nan, 'Beacon Hill', 'Back Bay',
#        'South Boston', 'Chinatown', 'Allston/Brighton', 'Charlestown',
#        'Kendall Square/MIT', 'Dorchester', 'Teele Square',
#        'Jamaica Plain', 'Inman Square', 'Harvard Square', 'Fenway',
#        'Mission Hill', 'Porter Square', 'North Cambridge', 'West Roxbury',
#        'Coolidge Corner'], dtype=object)

# %%
b.search_cat.unique()
# Out:
# array(['restaurants', 'coffee', 'newamerican', 'french', 'sandwiches',
#        'cafes', 'indpak', 'sushi', 'japanese', 'chinese', 'mexican',
#        'thai', 'pizza', 'donuts', 'bakeries', 'italian', 'vietnamese',
#        'ethnicmarkets'], dtype=object)

# %%
mask = b.categories.apply(lambda x: 'bars' in x)
b_check = b[mask]
b_check
# Out:
#               name                                            url  \
# 42         Deuxave         http://www.yelp.com/biz/deuxave-boston
# 43   Corner Tavern   http://www.yelp.com/biz/corner-tavern-boston
# 52    Sister Sorel    http://www.yelp.com/biz/sister-sorel-boston
# 63         Mistral         http://www.yelp.com/biz/mistral-boston
# 67     West Bridge  http://www.yelp.com/biz/west-bridge-cambridge
# 142       Genki Ya        http://www.yelp.com/biz/genki-ya-boston
# 166       Genki Ya        http://www.yelp.com/biz/genki-ya-boston
# 239           OTTO            http://www.yelp.com/biz/otto-boston
# 297      Anchovies       http://www.yelp.com/biz/anchovies-boston
#
#      review_count                                         categories  rating  \
# 42            310          [american (new), newamerican, bars, bars]     4.0
# 43            181          [bars, bars, american (new), newamerican]     4.0
# 52             65          [bars, bars, american (new), newamerican]     4.0
# 63            675                       [french, french, bars, bars]     4.0
# 67            271  [bars, bars, american (new), newamerican, fren...     4.0
# 142           204  [sushi bars, sushi, japanese, japanese, bars, ...     4.0
# 166           204  [sushi bars, sushi, japanese, japanese, bars, ...     4.0
# 239           107                         [pizza, pizza, bars, bars]     4.0
# 297           269                     [italian, italian, bars, bars]     4.0
#
#                                           snippet_text  \
# 42   All I know is that we left much happier than w...
# 43   I ordered the bacon and pepperjack grilled che...
# 52   I came here this weekend after eating at Tremo...
# 63   This place really is that good. They even scre...
# 67   First of all you need to know that my father i...
# 142  Enjoyed the spicy tuna, salmon and yellowtail ...
# 166  Enjoyed the spicy tuna, salmon and yellowtail ...
# 239  Can only review them based on delivery, not th...
# 297  I lived in the south end for three years and t...
#
#                                               location        neighborhood  \
# 42   {"city": "Boston", "display_address": ["371 Co...            Back Bay
# 43   {"cross_streets": "Massachusetts Ave & Herefor...            Back Bay
# 52   {"city": "Boston", "display_address": ["645 Tr...           South End
# 63   {"cross_streets": "Clarendon St & Cahners Pl",...            Back Bay
# 67   {"city": "Cambridge", "display_address": ["1 K...  Kendall Square/MIT
# 142  {"cross_streets": "Van Rensselaer Pl & Stuart ...                 NaN
# 166  {"cross_streets": "Van Rensselaer Pl & Stuart ...                 NaN
# 239  {"city": "Boston", "display_address": ["888 Co...    Allston/Brighton
# 297  {"cross_streets": "Braddock Park & Holyoke St"...           South End
#
#       latitude  longitude   search_cat             cuisine estab
# 42   42.349521 -71.089166  newamerican          [american]  bars
# 43   42.350159 -71.089432  newamerican          [american]  bars
# 52   42.342191 -71.075072  newamerican          [american]  bars
# 63   42.348158 -71.072759       french            [french]  bars
# 67   42.366569 -71.090187       french  [american, french]  bars
# 142  42.351246 -71.064722        sushi          [japanese]  bars
# 166  42.351246 -71.064722     japanese          [japanese]  bars
# 239  42.350441 -71.115257        pizza           [italian]  bars
# 297  42.343939 -71.077598      italian           [italian]  bars

# %%
b['location'] = b['location'].apply(lambda x: json.loads(x))

# %%
location = pd.json_normalize(b['location'])
b['city'] = location['city']

# %%
b
# Out:
#                              name  \
# 0                      Wheelhouse
# 1                  Tenoch Mexican
# 2                            O Ya
# 3                          Locale
# 4                  Neptune Oyster
# ..                            ...
# 338                     El Madina
# 339           The Shops at Porter
# 340  Bazaar International Gourmet
# 341          G Mart 2 Supermarket
# 342    Bonne Chance Cafe & Bakery
#
#                                                    url  review_count  \
# 0          http://www.yelp.com/biz/wheelhouse-boston-3           101
# 1        http://www.yelp.com/biz/tenoch-mexican-boston           121
# 2                  http://www.yelp.com/biz/o-ya-boston           450
# 3                http://www.yelp.com/biz/locale-boston           121
# 4        http://www.yelp.com/biz/neptune-oyster-boston          2487
# ..                                                 ...           ...
# 338           http://www.yelp.com/biz/el-madina-revere             8
# 339  http://www.yelp.com/biz/the-shops-at-porter-ca...            79
# 340  http://www.yelp.com/biz/bazaar-international-g...            52
# 341  http://www.yelp.com/biz/g-mart-2-supermarket-b...            48
# 342  http://www.yelp.com/biz/bonne-chance-cafe-and-...            22
#
#                                             categories  rating  \
# 0    [breakfast & brunch, breakfast_brunch, burgers...     4.5
# 1                                   [mexican, mexican]     4.5
# 2                                 [japanese, japanese]     4.5
# 3                     [italian, italian, pizza, pizza]     4.5
# 4          [seafood, seafood, live/raw food, raw_food]     4.5
# ..                                                 ...     ...
# 338  [mediterranean, mediterranean, middle eastern,...     4.5
# 339  [japanese, japanese, ethnic food, ethnicmarket...     4.0
# 340     [ethnic food, ethnicmarkets, grocery, grocery]     4.0
# 341     [grocery, grocery, ethnic food, ethnicmarkets]     4.0
# 342  [bakeries, bakeries, coffee & tea, coffee, eth...     4.0
#
#                                           snippet_text  \
# 0    After going to Wheelhouse, you'll never order ...
# 1    So it's official, folks. We've finished our sa...
# 2    My husband and I came here to celebrate our 20...
# 3    Truly thankful that we stumbled on Locale whil...
# 4    Best lobster roll on the whole trip..... and I...
# ..                                                 ...
# 338  I went in around closing tonight because I was...
# 339  This is like a small (chibi) version of the Ja...
# 340  The Bazaar at 1432 Beacon Street, Brookline Ma...
# 341  Everything is inexpensive! I was so surprised ...
# 342  I have to say.... I've not had anything else o...
#
#                                               location        neighborhood  \
# 0    {'cross_streets': 'Milk St & Batterymarch Arm'...  Financial District
# 1    {'city': 'Boston', 'display_address': ['3 Lewi...           North End
# 2    {'city': 'Boston', 'display_address': ['9 E St...          Waterfront
# 3    {'cross_streets': 'Fleet St & Tileston St', 'c...           North End
# 4    {'cross_streets': 'Hull St & Stillman St', 'ci...           North End
# ..                                                 ...                 ...
# 338  {'city': 'Revere', 'display_address': ['148 Sq...                 NaN
# 339  {'city': 'Cambridge', 'display_address': ['Uni...       Porter Square
# 340  {'city': 'Brookline', 'display_address': ['143...     Coolidge Corner
# 341  {'cross_streets': 'Beach St & Tufts St', 'city...          Waterfront
# 342  {'cross_streets': 'Traverse St & Market St', '...                 NaN
#
#       latitude  longitude     search_cat                          cuisine  \
# 0    42.357926 -71.053962    restaurants  [american, breakfast, sandwich]
# 1    42.363309 -71.051800    restaurants                        [mexican]
# 2    42.351408 -71.056867    restaurants                       [japanese]
# 3    42.365085 -71.053187    restaurants                        [italian]
# 4    42.363618 -71.056012    restaurants                        [seafood]
# ..         ...        ...            ...                              ...
# 338  42.423248 -71.009514  ethnicmarkets     [mediterranean, middle_east]
# 339  42.387192 -71.118778  ethnicmarkets                       [japanese]
# 340  42.341065 -71.126470  ethnicmarkets                               []
# 341  42.351569 -71.058365  ethnicmarkets                               []
# 342  42.364044 -71.059463  ethnicmarkets                               []
#
#            estab       city
# 0     restaurant     Boston
# 1     restaurant     Boston
# 2     restaurant     Boston
# 3     restaurant     Boston
# 4     restaurant     Boston
# ..           ...        ...
# 338   restaurant     Revere
# 339   restaurant  Cambridge
# 340   restaurant  Brookline
# 341   restaurant     Boston
# 342  coffee/cafe     Boston
#
# [343 rows x 14 columns]

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=b, y="search_cat", hue="rating", bins=5, multiple="stack", palette="magma")
plt.title("Distribution of Ratings across search categories")
plt.show()

# %% [markdown]
# ## Ideas

# %% [markdown]
# - could create a quiz-type format where the user goes sequentially through questions to filter the data **could include option to skip, go back etc.**
#     - start with map of boston: choose your neighborhood
#     - what type of restaurant are you looking for?
#     - what kind of food are you in the mood for?
#     - do you have any dietary restrictions?
#     - this might be ambitious but could have the map dynamically updating points
#     - RESULT: best result/highest rating, with information about restaurant, other suggestions if the user is not interested
# - could also focus on a particular search category and try finding values from the text snippets for additional details (i.e. coffee/cafe finder or pizza locator)
# - ADD OTHER IDEAS

# %%
b = b.drop(columns = ['search_cat'])

# %%
b = b.drop_duplicates(subset=['url'])

# %%
# b.sort_values(by=['na'])

# %%
# b.to_csv('boston_yelp_final.csv')

# %%
cities = b.city.unique()

cities = [x.upper() for x in cities]

print(cities)
# Out:
# ['BOSTON', 'NEWTON', 'CHARLESTOWN', 'CAMBRIDGE', 'WATERTOWN', 'MEDFORD', 'QUINCY', 'SOMERVILLE', 'JAMAICA PLAIN', 'BROOKLINE', 'ALLSTON', 'DORCHESTER', 'REVERE', 'CHELSEA', 'SAUGUS', 'BELMONT', 'MALDEN', 'ROXBURY CROSSING', 'WEST ROXBURY', 'BOSTONN', 'EVERETT']

# %%
g = [feature for feature in g['features'] if feature['properties']['TOWN'] in cities]

# %%
geos = {
    'type': 'FeatureCollection',
    'features': g,
}

# %%
# with open("cities.json", "w") as outfile:
#     json.dump(geos, outfile)

# %%
cuisines = list(cus_map.keys())

# %%
cuisines
# Out:
# ['american',
#  'breakfast',
#  'mexican',
#  'japanese',
#  'vietnamese',
#  'italian',
#  'seafood',
#  'mediterranean',
#  'sandwich',
#  'healthy',
#  'spanish',
#  'asian_fusion',
#  'indian_pakistani',
#  'french',
#  'chinese',
#  'latin',
#  'thai',
#  'middle_east',
#  'polish_ukr']

# %%
import csv
with open("cuisines.csv","w") as f:
    wr = csv.writer(f,delimiter="\n")
    wr.writerow(cuisines)

# %%
cuisines = pd.DataFrame(cuisines, columns=["cuisine"])
cuisines.to_csv('cuisines.csv', index=False)
